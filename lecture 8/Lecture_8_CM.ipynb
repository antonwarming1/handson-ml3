# %% [markdown]
# # Confusion Matrix Analysis and Visualization
# This notebook demonstrates how to create, analyze, and visualize confusion matrices using Python.
#
# ## Setup
# First, we'll import the necessary libraries and create sample data.

# %%
# Import necessary libraries
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Create sample data
y_true = np.array([0, 1, 0, 1, 1, 0, 1, 0, 1, 0])
y_pred = np.array([0, 1, 0, 1, 0, 0, 1, 1, 1, 1])

# %%
# Create and display the confusion matrix
cm = confusion_matrix(y_true, y_pred)
print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[3 2]
#  [1 4]]

# %% [markdown]
# ## Calculate Basic Metrics
# Let's calculate and display the fundamental classification metrics.

# %%
# Calculate basic metrics
accuracy = accuracy_score(y_true, y_pred)
precision = precision_score(y_true, y_pred)
recall = recall_score(y_true, y_pred)
f1 = f1_score(y_true, y_pred)

print("Basic Metrics:")
print(f"Accuracy: {accuracy:.3f}")
print(f"Precision: {precision:.3f}")
print(f"Recall: {recall:.3f}")
print(f"F1 Score: {f1:.3f}")
# Out:
# Basic Metrics:
# Accuracy: 0.700
# Precision: 0.667
# Recall: 0.800
# F1 Score: 0.727

# %% [markdown]
# ## Detailed Classification Report
# The classification report provides a more detailed overview of the model's performance.

# %%
# Display detailed classification report
print("Classification Report:")
print(classification_report(y_true, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.75      0.60      0.67         5
#            1       0.67      0.80      0.73         5
#
#     accuracy                           0.70        10
#    macro avg       0.71      0.70      0.70        10
# weighted avg       0.71      0.70      0.70        10

# %% [markdown]
# ## Visualization
# Let's create visual representations of the confusion matrix.

# %%
# Visualization function
def plot_confusion_matrix(cm, labels=['Negative', 'Positive']):
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=labels, yticklabels=labels)
    plt.title('Confusion Matrix')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.show()

# Visualize the confusion matrix
plot_confusion_matrix(cm)

# %% [markdown]
# ## Normalized Confusion Matrix
# Finally, let's create a normalized version of the confusion matrix.

# %%
# Create a normalized confusion matrix visualization
cm_normalized = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

plt.figure(figsize=(8, 6))
sns.heatmap(cm_normalized, annot=True, fmt='.2f', cmap='Blues',
            xticklabels=['Negative', 'Positive'],
            yticklabels=['Negative', 'Positive'])
plt.title('Normalized Confusion Matrix')
plt.ylabel('True Label')
plt.xlabel('Predicted Label')
plt.show()
